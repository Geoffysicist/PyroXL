# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
hours = np.linspace(0,100,50)
y = np.exp(-0.0858*hours)

# %%
plt.scatter(hours,y)

# %%
import math as m

# %%
m.exp(-0.0858*96)
# Out:
# 0.00026473003158264364
